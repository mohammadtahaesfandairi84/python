# %%
import pyautogui as robo
import pyperclip
import time

# %%
for i in range(1, 51):
    time.sleep(1)
    pyperclip.copy("تولدت مبارک پدر عزیزم🌹🌹🌹🎉")
    robo.hotkey("ctrl", "v")
    robo.press("enter")
